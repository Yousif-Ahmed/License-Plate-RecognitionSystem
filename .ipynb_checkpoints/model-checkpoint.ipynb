# %% [markdown]
# ## import all needed liberary

# %%
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline
from skimage.color import rgb2gray,rgb2hsv
from skimage.exposure import equalize_adapthist 
from skimage import filters
from skimage import measure
from skimage.draw import polygon
import matplotlib.pyplot as plt
import numpy as np
import math
import cv2
from skimage.draw import rectangle
import imutils
from skimage.exposure import histogram
from matplotlib.pyplot import bar
import ArabicOcr

# %%
img_data1 =cv2.imread("dataset\data40.jpeg")
img_data1 = imutils.resize(img_data1 , width = 500)
io.imshow(img_data1)

# %%
def show_image (img):
    fig = plt.figure()
    plt.gray()
    plt.imshow(img)
    plt.axis('off')
    plt.show()

def image_preprocessing (img):
    '''
        in this function we are going to applying different preprocessing 
        techniques in the input image 

        prams:
                img 
    '''
    '''
   
    '''
    # initialize the rectangular and square kernels to be applied to the image,
    # then initialize the list of license plate regions
    rectKernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 3))
    squareKernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    

    # convert the image to grayscale, and apply the blackhat operation
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, rectKernel)

    # find regions in the image that are light
    light = cv2.morphologyEx(gray, cv2.MORPH_CLOSE, squareKernel)
    light = cv2.threshold(light, 50, 255, cv2.THRESH_BINARY)[1]

    # compute the Scharr gradient representation of the blackhat image and scale the
    # resulting image into the range [0, 255]
    gradX = cv2.Sobel(blackhat,ddepth = cv2.CV_32F,dx = 1, dy = 0, ksize = -1)
    
    gradX = np.absolute(gradX)
    (minVal, maxVal) = (np.min(gradX), np.max(gradX))
    gradX = (255 * ((gradX - minVal) / (maxVal - minVal))).astype("uint8")

    # blur the gradient representation, apply a closing operating, and threshold the
    # image using Otsu's method
    gradX = cv2.GaussianBlur(gradX, (9, 9), 0)
    gradX = cv2.morphologyEx(gradX, cv2.MORPH_CLOSE, rectKernel)
    thresh = cv2.threshold(gradX, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

    # perform a series of erosions and dilations on the image
    thresh = cv2.erode(thresh, None, iterations = 2)
    thresh = cv2.dilate(thresh, None, iterations = 2)

    # take the bitwise 'and' between the 'light' regions of the image, then perform
    # another series of erosions and dilations
    thresh = cv2.bitwise_and(thresh, thresh, mask = light)
    thresh = cv2.dilate(thresh, None, iterations = 6)
    thresh = cv2.erode(thresh, None, iterations = 8)
    blur = cv2.GaussianBlur(thresh,(5,5),0)

    return blur , gray
   

w = img_data1.shape[0]
h = img_data1.shape[1]
preprocessed_img  , gray_img= image_preprocessing(img_data1)
show_image(preprocessed_img)
io.imsave('result1.jpg' , preprocessed_img)
print(gray_img)
# Out:
# [[255 255 255 ...   1   4   4]
#  [255 255 255 ...   1   3   3]
#  [255 255 255 ...   0   1   2]
#  ...
#  [136 141 138 ... 116 118 118]
#  [147 144 142 ... 116 117 119]
#  [147 134 144 ... 117 117 118]]

# %%
def edge_img_processing(edge_img , img ):
    #Thresholding:
    #gray = cv2.cvtColor(edge_img, cv2.COLOR_BGR2GRAY)
    #T, edge_img_t = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU + cv2.THRESH_BINARY_INV)
    edge_img_t=edge_img
    #Finding contours (only need the external contour):
    cnts, _ = cv2.findContours(edge_img_t, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    #cnts=sorted(cnts, key = cv2.contourArea, reverse = false)[:50] and 

    plates = []
    for i, c in enumerate(cnts):
        x,y,w,h = cv2.boundingRect(c)
        area = w *h 
        aspect_ratio = w/h 
        plate = img[y:y+h, x:x+w]
        window =img_data1[y:y+h, x:x+w]
        avg_blue_ch = np.sum(window[:,:,2])/ (w*h)              
        avg_red_ch = np.sum(window[:,:,0])/ (w*h)  
        avg_green_ch = np.sum(window[:,:,1])/ (w*h)              

        if (1.6< aspect_ratio < 5 and 900<area < 6500 and avg_red_ch >100 and 200>avg_green_ch>100 and avg_blue_ch>100  or True):
                print(i ,avg_red_ch ,avg_green_ch,avg_blue_ch)
                print (aspect_ratio , area)
                
        
                ints = 0
                sz = np.shape(plate)
                print (sz)
                for j in range (0,sz[0]):
                    for k in range (0,sz[1]):
                            ints = ints+plate[j][k]

                    #print (ints)
                smin = sz[0]*sz[1]*255*0.4
                smax = sz[0]*sz[1]*255*0.9
                plates.append(img_data1[y-1:y+h+1, x-1:x+w+1])
                #cv2.rectangle(img_data1, (x, y), (x + w, y + h), (100,0,0), 1)
            
            #print (ints,sm , plate[0])
           # if (ints > smin and ints < smax):
             

            

    #plates.sort(key=lambda by_x: by_x[1])
    #Writing the found contour into a folder
    
    print ("ssszzz")
    print (len(plates))
    for i, char in enumerate(plates):
        cv2.imwrite(f'Scannedplates/Char{i}.jpg', char )

    return  edge_img_t , img, plates

edge_img , img ,plates= edge_img_processing(preprocessed_img , gray_img)
print(np.array(plates).shape)
# Out:
# 0 112.31428571428572 112.77142857142857 102.34285714285714
# 1.4 35
# (5, 7)
# 1 88.14924125514403 81.92001028806584 66.68910751028807
# 2.3703703703703702 15552
# (81, 192)
# 2 77.33333333333333 64.5 55.833333333333336
# 1.2 30
# (5, 6)
# 3 189.14950980392157 187.97549019607843 181.81617647058823
# 0.7083333333333334 408
# (24, 17)
# 4 100.56985294117646 86.5845588235294 75.69485294117646
# 1.0625 272
# (16, 17)
# 5 115.55555555555556 105.66666666666667 91.28282828282828
# 1.2222222222222223 99
# (9, 11)
# 6 207.38846153846154 196.86282051282052 178.58205128205128
# 1.1538461538461537 780
# (26, 30)
# 7 230.22142857142856 213.29285714285714 193.0
# 0.7142857142857143 140
# (14, 10)
# 8 26.057142857142857 28.742857142857144 24.942857142857143
# 1.4 35
# (5, 7)
# 9 31.742857142857144 53.08571428571429 45.02857142857143
# 0.7142857142857143 35
# (7, 5)
# 10 102.56666666666666 94.32222222222222 75.5
# 2.5 90
# (6, 15)
# 11 79.92 78.28 66.56
# 1.0 25
# (5, 5)
# 12 103.78571428571429 98.45238095238095 83.57142857142857
# 1.1666666666666667 42
# (6, 7)
# 13 98.15 103.65 97.2
# 1.25 80
# (8, 10)
# 14 104.68131868131869 111.0 104.07692307692308
# 0.5384615384615384 91
# (13, 7)
# 15 177.41034482758621 168.88275862068966 160.1448275862069
# 1.0344827586206897 870
# (29, 30)
# 16 181.46095048188766 175.88667331339315 163.5260884014623
# 1.1568627450980393 3009
# (51, 59)
# 17 63.42483660130719 55.63289760348584 52.09912854030501
# 1.2592592592592593 918
# (27, 34)
# 18 28.950617283950617 36.29320987654321 35.907407407407405
# 1.0 324
# (18, 18)
# 19 51.05714285714286 60.2 58.4984126984127
# 0.7142857142857143 315
# (21, 15)
# 20 45.214285714285715 47.666666666666664 42.976190476190474
# 1.1666666666666667 42
# (6, 7)
# 21 30.363636363636363 38.46969696969697 33.56818181818182
# 3.6666666666666665 132
# (6, 22)
# 22 26.8 39.68888888888889 33.08888888888889
# 0.5555555555555556 45
# (9, 5)
# 23 92.11977188663607 92.28944666427502 87.4765639496765
# 1.5414847161572052 80837
# (229, 353)
# ssszzz
# 24
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# C:\Users\YOUSIF~1\AppData\Local\Temp/ipykernel_3436/36109816.py in <module>
#      53     return  edge_img_t , img, plates
#      54
# ---> 55 edge_img , img ,plates= edge_img_processing(preprocessed_img , gray_img)
#      56 print(np.array(plates).shape)
#
# C:\Users\YOUSIF~1\AppData\Local\Temp/ipykernel_3436/36109816.py in edge_img_processing(edge_img, img)
#      49     print (len(plates))
#      50     for i, char in enumerate(plates):
# ---> 51         cv2.imwrite(f'Scannedplates/Char{i}.jpg', char )
#      52
#      53     return  edge_img_t , img, plates
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
# !pip install ArabicOcr
# Out:
# Requirement already satisfied: ArabicOcr in c:\users\yousif-ahmed\anaconda3\lib\site-packages (1.1.6)
# Requirement already satisfied: easyocr in c:\users\yousif-ahmed\appdata\roaming\python\python39\site-packages (from ArabicOcr) (1.4.1)
# Requirement already satisfied: Pillow<8.3.0 in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from easyocr->ArabicOcr) (8.2.0)
# Requirement already satisfied: scikit-image in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from easyocr->ArabicOcr) (0.19.1)
# Requirement already satisfied: scipy in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from easyocr->ArabicOcr) (1.7.1)
# Requirement already satisfied: python-bidi in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from easyocr->ArabicOcr) (0.4.2)
# Requirement already satisfied: numpy in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from easyocr->ArabicOcr) (1.20.3)
# Requirement already satisfied: torch in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from easyocr->ArabicOcr) (1.10.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from easyocr->ArabicOcr) (0.11.2)
# Requirement already satisfied: opencv-python-headless in c:\users\yousif-ahmed\appdata\roaming\python\python39\site-packages (from easyocr->ArabicOcr) (4.5.5.62)
# Requirement already satisfied: PyYAML in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from easyocr->ArabicOcr) (6.0)
# Requirement already satisfied: typing-extensions in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from torch->easyocr->ArabicOcr) (3.10.0.2)
# Requirement already satisfied: six in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from python-bidi->easyocr->ArabicOcr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from scikit-image->easyocr->ArabicOcr) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from scikit-image->easyocr->ArabicOcr) (1.1.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from scikit-image->easyocr->ArabicOcr) (2021.7.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from scikit-image->easyocr->ArabicOcr) (2.6.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from scikit-image->easyocr->ArabicOcr) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\yousif-ahmed\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->easyocr->ArabicOcr) (3.0.4)
# WARNING: Ignoring invalid distribution -illow (c:\users\yousif-ahmed\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\yousif-ahmed\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\yousif-ahmed\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\yousif-ahmed\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\yousif-ahmed\anaconda3\lib\site-packages)

# %%
def Hough_Transform (img):
    img_shape = img.shape
    # image width and height
    x_max = img_shape[0]
    y_max = img_shape[1]
    
    theta_max = 1.0 * math.pi
    theta_min = 0.0
    
    r_min =0 
    r_max = math.hypot(x_max ,y_max)
    
    r_dim =200
    theta_dim =300
    
    houghSpace = np.zeros((r_dim , theta_dim))
    
    for x in range (x_max):
        for y in range(y_max):
            if img[x,y] ==0:continue
            for itheta  in range (theta_dim):
                theta = 1.0 *  itheta * theta_max /  theta_dim
                r = x * np.cos(theta) + y * np.sin(theta)
                ir = r_dim * (1.0 * r) /r_max
                
                houghSpace[np.round(ir).astype('int'),np.round(itheta).astype('int')]=  houghSpace[np.round(ir).astype('int'),np.round(itheta).astype('int')]+1
 
Hough_Transform(contours_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\YOUSIF~1\AppData\Local\Temp/ipykernel_18064/875290835.py in <module>
#      26                 houghSpace[np.round(ir).astype('int'),np.round(itheta).astype('int')]=  houghSpace[np.round(ir).astype('int'),np.round(itheta).astype('int')]+1
#      27
# ---> 28 Hough_Transform(contours_image)
#      29
#      30
#
# NameError: name 'contours_image' is not defined

# %%
'''
    imghsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV).astype("float32")
    (h, s, v) = cv2.split(imghsv)
    s = (s*1.29)
    s = np.clip(s,0,255)
    imghsv = cv2.merge([h,s,v])
    imgrgb = cv2.cvtColor(imghsv.astype("uint8"), cv2.COLOR_HSV2BGR)
    gray= cv2.cvtColor(imgrgb , cv2.COLOR_BGR2GRAY)    # convert image to grayscale
    #gray = cv2.bilateralFilter(gray_img, 11, 17, 17)
    edged = cv2.Canny(gray, 180, 250)
   
    #equalized_image = equalize_adapthist(gray_img) # applaying histogram equalization 
    #edged = Sobel(gray) # applaying edge detection using sobel algorithm  
    # we need to discuss the best way to get the best threshold 
    #result = ((edged >0.1))  # convert image to binary using thresholding value
    '''

# %%
  '''
    ax.imshow(contours_image)
    for contour in contours:
            rr, cc = polygon(contour[:, 0], contour[:, 1], contours_image.shape)
            contours_image[rr, cc] = 0

            ax.plot(contour[:, 1], contour[:, 0], linewidth=2)
    ax.axis('Image')
    ax.set_xticks([])
    ax.set_yticks([])
    plt.show()
    
     #imghsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV).astype("float32")
    #(h, s, v) = cv2.split(imghsv)
    #s = (s*1.29)
    #s = np.clip(s,0,255)
    #imghsv = cv2.merge([h,s,v])
    #imgrgb = cv2.cvtColor(imghsv.astype("uint8"), cv2.COLOR_HSV2BGR)

    gray= cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)    # convert image to grayscale
    blur=cv2.GaussianBlur(gray,(7,7),0)
    #edged = cv2.Canny(gray, 150, 250)
    _,bin_img=cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    #ret,bin_img = cv2.threshold(gray,0,255,cv2.THRESH_OTSU)
    #edged = cv2.Canny(gray, 30, 250)
    #equalized_image = equalize_adapthist(gray_img) # applaying histogram equalization 
    #edged = Sobel(gray) # applaying edge detection using sobel algorithm  
    # we need to discuss the best way to get the best threshold 
    #result = ((edged >0.1))  # convert image to binary using thresholding value 
    kernel1 = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
    kernel2 = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))

    closing = cv2.morphologyEx(bin_img, cv2.MORPH_CLOSE, kernel1,  iterations=4)
    #opening = cv2.morphologyEx(equal_histogram, cv2.MORPH_OPEN, kernel2, iterations=15)
    #sub_morp_image = cv2.subtract(equal_histogram,opening)
    #ret,thresh_image = cv2.threshold(noise_removal,0,255,cv2.THRESH_OTSU)
    #canny_image = cv2.Canny(thresh_image,150,250)
    #closing = cv2.morphologyEx(canny_image, cv2.MORPH_CLOSE, kernel1,  iterations=6)
    opening = cv2.morphologyEx(closing, cv2.MORPH_OPEN, kernel2, iterations=10)


    
    '''

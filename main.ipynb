# %% [markdown]
# # Imports

# %%
from PlateDetection import *
from CharacterRecognition import *

# %% [markdown]
# # Plate Detection

# %%
img_data1 = read_image("dataset\data2.jpeg")   
preprocessed_img  , gray_img= image_preprocessing(img_data1)
plates= plateDetection(preprocessed_img , img_data1)

# %% [markdown]
# # Plate Recognition

# %%
for plateImage in plates:
    plateImage=cv2.cvtColor(plateImage,cv2.COLOR_BGR2GRAY)
    txt =readPlate(plateImage)
    if txt !="":
        print("text :  " + txt)

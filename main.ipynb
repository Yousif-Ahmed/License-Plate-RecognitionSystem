# %% [markdown]
# # Imports

# %%
from PlateDetection import *
from CharacterRecognition import *

# %% [markdown]
# # Plate Detection

# %%
img_data1 = read_image("dataset\data15.jpeg")   
preprocessed_img  , gray_img= image_preprocessing(img_data1)
plates= plateDetection(preprocessed_img , img_data1)

# %% [markdown]
# # Plate Recognition

# %%
for imgName in os.listdir('plates'):
    plateImage=cv2.imread('plates/'+imgName,cv2.IMREAD_GRAYSCALE)
    txt =readPlate(plateImage)
    if txt !="":
        print("text :  " + txt)
# Out:
# text :   ج ٨ ٢ ٨
